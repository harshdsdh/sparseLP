# %% [markdown]
# <a href="https://colab.research.google.com/github/harshdsdh/sparseLP/blob/main/SAGE_Karate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install networkx
# !pip install torch_geometric
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (3.4.2)
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.11.15)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.4.26)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.6 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1

# %%
import torch
import torch.nn.functional as F
import networkx as nx
from torch_geometric.nn import GCNConv
from torch_geometric.nn import SAGEConv
from torch_geometric.transforms import RandomLinkSplit
from torch_geometric.utils import negative_sampling
from torch.nn import Linear

from sklearn.metrics import roc_auc_score, average_precision_score
import numpy as np
from tqdm import tqdm

# %%
import matplotlib.pyplot as plt
from torch_geometric.utils import from_networkx, to_networkx
import pandas as pd

# %%
param_grid = {
    'hidden_channels': [2, 4, 8, 16, 32, 64],
}

G = nx.karate_club_graph()
data = from_networkx(G)
data.x = torch.eye(data.num_nodes)

# %%
class SAGELinkPredictor(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels):
        super().__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels, aggr='mean')
        self.conv2 = SAGEConv(hidden_channels, hidden_channels, aggr='mean')


    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return x

    def decode(self, z, edge_label_index):
        return (z[edge_label_index[0]] * z[edge_label_index[1]]).sum(dim=1)

# %%
def train(model, optimizer, data):
    model.train()
    optimizer.zero_grad()
    z = model.forward(data.x, data.edge_index)
    pred = model.decode(z, data.edge_label_index)
    loss = F.binary_cross_entropy_with_logits(pred, data.edge_label)
    loss.backward()
    optimizer.step()
    return loss.item()

def test(model, data):
    model.eval()
    with torch.no_grad():
        z = model(data.x, data.edge_index)
        pred = model.decode(z, data.edge_label_index).sigmoid().cpu().numpy()
    y_true = data.edge_label.cpu().numpy()
    auc = roc_auc_score(y_true, pred)
    ap = average_precision_score(y_true, pred)
    return auc, ap

# %%
results = []
loss_curves = {}

for run in range(10):
  transform = RandomLinkSplit(is_undirected=True, add_negative_train_samples=True,neg_sampling_ratio=2)
  train_data, val_data, test_data = transform(data)

  for hidden in param_grid['hidden_channels']:

    model = SAGELinkPredictor(data.num_features, hidden)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    losses = []
    for epoch in range(100):

      loss = train(model, optimizer, train_data)
      losses.append(loss)

    auc, ap = test(model, test_data)
    results.append({
        'run': run,
        'hidden': hidden,
        'auc': auc,
        'average_precision': ap
    })

    loss_curves[(run, hidden)] = losses

# %%
df = pd.DataFrame(results)
df_res = df.groupby(['hidden'])[['auc', 'average_precision']].mean()
print(df.groupby(['hidden'])[['auc', 'average_precision']].mean())
# Out:
#              auc  average_precision
# hidden
# 2       0.613444           0.460236
# 4       0.634556           0.512924
# 8       0.621556           0.480830
# 16      0.597667           0.429182
# 32      0.612667           0.433778
# 64      0.599000           0.424129

# %%
ax = df_res.plot(kind='bar', figsize=(8, 5))
plt.title("SAGE Performance vs Hidden Size")
plt.xlabel("Hidden Size")
plt.ylabel("Score")
plt.ylim(0.4, 0.8)

plt.legend(title="Metric")
plt.tight_layout()
plt.show()

# %%
def compute_bonus(u, v, data):
  try:
      Cu = data.nodes[u].get('community')
      Cv = data.nodes[v].get('community')
      if Cu == Cv:
          return 0

      deg_u = data.degree(u)
      deg_v = data.degree(v)

      nodes_Cu = [n for n in data.nodes if data.nodes[n].get('community') == Cu]
      avg_deg_Cu = np.mean([data.degree(n) for n in nodes_Cu]) if nodes_Cu else 0

      nodes_Cv = [n for n in data.nodes if data.nodes[n].get('community') == Cv]
      avg_deg_Cv = np.mean([data.degree(n) for n in nodes_Cv]) if nodes_Cv else 0

      neighbors_u = list(data.neighbors(u))
      neighbors_v = list(data.neighbors(v))


      if deg_u < avg_deg_Cu and deg_v > avg_deg_Cv:
          return len(list(nx.common_neighbors(data, u, v)))
      if deg_v < avg_deg_Cv and deg_u > avg_deg_Cu :
          return len(list(nx.common_neighbors(data, u, v)))
  except:
      return 0
  return 0

# %%
def train_modified(model, optimizer, data, nxGraph, bonus_weight):



  model.train()
  optimizer.zero_grad()
  z = model.forward(data.x, data.edge_index)
  pred = model.decode(z, data.edge_label_index)
  loss = F.binary_cross_entropy_with_logits(pred, data.edge_label)

  pos_edges = data.edge_label_index[:, data.edge_label == 1].T
  bonus = 0.0
  for u, v in pos_edges.tolist():
      bonus += compute_bonus(u, v, nxGraph)

  loss = loss - bonus_weight * bonus


  loss.backward()
  optimizer.step()
  return loss.item()

def test_modified(model, data):
    model.eval()
    with torch.no_grad():
        z = model(data.x, data.edge_index)
        pred = model.decode(z, data.edge_label_index).sigmoid().cpu().numpy()
    y_true = data.edge_label.cpu().numpy()
    auc = roc_auc_score(y_true, pred)
    ap = average_precision_score(y_true, pred)
    return auc, ap

# %%
param_grid = {
    'hidden_channels': [4, 8, 16, 32, 64],
    'bonus_weight': [0, 0.001, 0.01, 0.1]
}

G = nx.karate_club_graph()
data = from_networkx(G)
data.x = torch.eye(data.num_nodes)

# %%
results = []
loss_curves = {}

for run in range(10):

  transform = RandomLinkSplit(is_undirected=True, add_negative_train_samples=True,neg_sampling_ratio=2)
  train_data, val_data, test_data = transform(data)

  G_train_nx = to_networkx(train_data, to_undirected=True)
  communities = nx.community.louvain_communities(G_train_nx)

  # Map nodes to communities
  community_map = {}
  for i, comm in enumerate(communities):
      for node in comm:
          community_map[node] = i

  # Add community attribute to nodes
  for node in G_train_nx.nodes():
      G_train_nx.nodes[node]['community'] = community_map.get(node, 0)


  for hidden in param_grid['hidden_channels']:
    for w in param_grid['bonus_weight']:

      model = SAGELinkPredictor(data.num_features, hidden)
      optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
      losses = []
      for epoch in range(100):

        loss = train_modified(model, optimizer, train_data,G_train_nx,  w)
        losses.append(loss)

      auc, ap = test_modified(model, test_data)
      results.append({
          'run': run,
          'hidden': hidden,
          'bonus_w': w,
          'auc': auc,
          'average_precision': ap
      })

      loss_curves[(run, hidden, w)] = losses

# %%
results
# Out:
# [{'run': 0,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.6711111111111111),
#   'average_precision': np.float64(0.43704980656200165)},
#  {'run': 0,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5199999999999999),
#   'average_precision': np.float64(0.4127683172708012)},
#  {'run': 0,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6733333333333333),
#   'average_precision': np.float64(0.5219782926217008)},
#  {'run': 0,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.4488888888888889),
#   'average_precision': np.float64(0.33912406754854457)},
#  {'run': 0,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.5455555555555556),
#   'average_precision': np.float64(0.3510007911308221)},
#  {'run': 0,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5511111111111111),
#   'average_precision': np.float64(0.5212312470014653)},
#  {'run': 0,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5433333333333333),
#   'average_precision': np.float64(0.3940885977950793)},
#  {'run': 0,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5333333333333333),
#   'average_precision': np.float64(0.376412182807248)},
#  {'run': 0,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.6044444444444445),
#   'average_precision': np.float64(0.4037590534169818)},
#  {'run': 0,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5866666666666667),
#   'average_precision': np.float64(0.41398107221506003)},
#  {'run': 0,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6411111111111111),
#   'average_precision': np.float64(0.476335835772708)},
#  {'run': 0,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6244444444444444),
#   'average_precision': np.float64(0.4359818886574105)},
#  {'run': 0,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.6633333333333334),
#   'average_precision': np.float64(0.46859752019344547)},
#  {'run': 0,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5344444444444444),
#   'average_precision': np.float64(0.35102500304458684)},
#  {'run': 0,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6866666666666666),
#   'average_precision': np.float64(0.4866628417067013)},
#  {'run': 0,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5955555555555555),
#   'average_precision': np.float64(0.44431247963506026)},
#  {'run': 0,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.66),
#   'average_precision': np.float64(0.4780503592268298)},
#  {'run': 0,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6822222222222222),
#   'average_precision': np.float64(0.5254044667308213)},
#  {'run': 0,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6244444444444445),
#   'average_precision': np.float64(0.4250039954067414)},
#  {'run': 0,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5888888888888888),
#   'average_precision': np.float64(0.4278470624982253)},
#  {'run': 1,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.6844444444444445),
#   'average_precision': np.float64(0.5175703349476141)},
#  {'run': 1,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.3222222222222222),
#   'average_precision': np.float64(0.28300464558462496)},
#  {'run': 1,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6511111111111111),
#   'average_precision': np.float64(0.46125864504689795)},
#  {'run': 1,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.4755555555555555),
#   'average_precision': np.float64(0.33785233382509217)},
#  {'run': 1,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.6666666666666666),
#   'average_precision': np.float64(0.49133212528751297)},
#  {'run': 1,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.44),
#   'average_precision': np.float64(0.352725960096006)},
#  {'run': 1,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6111111111111112),
#   'average_precision': np.float64(0.42595711128252156)},
#  {'run': 1,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5466666666666666),
#   'average_precision': np.float64(0.37921433308024344)},
#  {'run': 1,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.42),
#   'average_precision': np.float64(0.2885310080659196)},
#  {'run': 1,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6344444444444445),
#   'average_precision': np.float64(0.4349814920145353)},
#  {'run': 1,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6533333333333333),
#   'average_precision': np.float64(0.45264151440235034)},
#  {'run': 1,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6066666666666667),
#   'average_precision': np.float64(0.38521446825546324)},
#  {'run': 1,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.6499999999999999),
#   'average_precision': np.float64(0.46220344748935716)},
#  {'run': 1,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6155555555555555),
#   'average_precision': np.float64(0.39901357611848)},
#  {'run': 1,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6355555555555555),
#   'average_precision': np.float64(0.44558802698956795)},
#  {'run': 1,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6933333333333334),
#   'average_precision': np.float64(0.45530664501998663)},
#  {'run': 1,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.4933333333333333),
#   'average_precision': np.float64(0.354872577104882)},
#  {'run': 1,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.508888888888889),
#   'average_precision': np.float64(0.35931561838962217)},
#  {'run': 1,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5466666666666666),
#   'average_precision': np.float64(0.36517367957397373)},
#  {'run': 1,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.62),
#   'average_precision': np.float64(0.4011360918453843)},
#  {'run': 2,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.43333333333333335),
#   'average_precision': np.float64(0.3289410894939164)},
#  {'run': 2,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5777777777777777),
#   'average_precision': np.float64(0.3651531239252977)},
#  {'run': 2,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5377777777777778),
#   'average_precision': np.float64(0.40725293214799735)},
#  {'run': 2,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.3977777777777778),
#   'average_precision': np.float64(0.29257002442467556)},
#  {'run': 2,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.4955555555555555),
#   'average_precision': np.float64(0.4077081664598764)},
#  {'run': 2,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.4277777777777778),
#   'average_precision': np.float64(0.30284278585815316)},
#  {'run': 2,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.4711111111111111),
#   'average_precision': np.float64(0.3107516451611254)},
#  {'run': 2,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5488888888888889),
#   'average_precision': np.float64(0.36773323393527996)},
#  {'run': 2,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.5033333333333333),
#   'average_precision': np.float64(0.48528212529544523)},
#  {'run': 2,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.4822222222222223),
#   'average_precision': np.float64(0.33668650218478546)},
#  {'run': 2,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5222222222222223),
#   'average_precision': np.float64(0.3387528463806114)},
#  {'run': 2,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5222222222222223),
#   'average_precision': np.float64(0.3497704522613716)},
#  {'run': 2,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.4855555555555556),
#   'average_precision': np.float64(0.3422844342343258)},
#  {'run': 2,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.44),
#   'average_precision': np.float64(0.32146628999300614)},
#  {'run': 2,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.4777777777777778),
#   'average_precision': np.float64(0.34864876260520544)},
#  {'run': 2,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5511111111111111),
#   'average_precision': np.float64(0.40690523644642007)},
#  {'run': 2,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.4),
#   'average_precision': np.float64(0.30994344371313454)},
#  {'run': 2,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.36444444444444446),
#   'average_precision': np.float64(0.2918051390055632)},
#  {'run': 2,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5022222222222222),
#   'average_precision': np.float64(0.327635534354436)},
#  {'run': 2,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5288888888888889),
#   'average_precision': np.float64(0.36818787946626463)},
#  {'run': 3,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.8022222222222223),
#   'average_precision': np.float64(0.8003580615660195)},
#  {'run': 3,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6755555555555555),
#   'average_precision': np.float64(0.5516600368195277)},
#  {'run': 3,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.46444444444444444),
#   'average_precision': np.float64(0.3480483956308347)},
#  {'run': 3,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.72),
#   'average_precision': np.float64(0.5694195136510126)},
#  {'run': 3,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.4211111111111111),
#   'average_precision': np.float64(0.34534397518331)},
#  {'run': 3,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6977777777777778),
#   'average_precision': np.float64(0.5088027528027528)},
#  {'run': 3,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5955555555555555),
#   'average_precision': np.float64(0.5360875824912684)},
#  {'run': 3,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7244444444444444),
#   'average_precision': np.float64(0.6162649607923442)},
#  {'run': 3,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.7222222222222222),
#   'average_precision': np.float64(0.5457928811654766)},
#  {'run': 3,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7977777777777777),
#   'average_precision': np.float64(0.650327639839835)},
#  {'run': 3,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.7933333333333332),
#   'average_precision': np.float64(0.6838561210873708)},
#  {'run': 3,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6177777777777778),
#   'average_precision': np.float64(0.46980978530749695)},
#  {'run': 3,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.7022222222222222),
#   'average_precision': np.float64(0.5541568959299605)},
#  {'run': 3,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7944444444444445),
#   'average_precision': np.float64(0.6269269005847953)},
#  {'run': 3,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.7777777777777779),
#   'average_precision': np.float64(0.6439168783792587)},
#  {'run': 3,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7144444444444444),
#   'average_precision': np.float64(0.4904370867030714)},
#  {'run': 3,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.808888888888889),
#   'average_precision': np.float64(0.6558211233211233)},
#  {'run': 3,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.8155555555555556),
#   'average_precision': np.float64(0.6598804399808704)},
#  {'run': 3,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.7622222222222222),
#   'average_precision': np.float64(0.5736935817805383)},
#  {'run': 3,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7577777777777777),
#   'average_precision': np.float64(0.5781968425675519)},
#  {'run': 4,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.6711111111111112),
#   'average_precision': np.float64(0.5163928408910802)},
#  {'run': 4,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6533333333333333),
#   'average_precision': np.float64(0.4785748181213381)},
#  {'run': 4,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5822222222222222),
#   'average_precision': np.float64(0.3784649092362341)},
#  {'run': 4,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6422222222222222),
#   'average_precision': np.float64(0.44177140260651526)},
#  {'run': 4,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.6855555555555556),
#   'average_precision': np.float64(0.5691344458011125)},
#  {'run': 4,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7),
#   'average_precision': np.float64(0.5602742857851217)},
#  {'run': 4,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6744444444444444),
#   'average_precision': np.float64(0.4995874495874496)},
#  {'run': 4,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6377777777777778),
#   'average_precision': np.float64(0.4569593141748116)},
#  {'run': 4,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.6377777777777778),
#   'average_precision': np.float64(0.43486883023402717)},
#  {'run': 4,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7777777777777777),
#   'average_precision': np.float64(0.6622759103641456)},
#  {'run': 4,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5211111111111111),
#   'average_precision': np.float64(0.3634478227990025)},
#  {'run': 4,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7244444444444444),
#   'average_precision': np.float64(0.624531507478876)},
#  {'run': 4,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.6288888888888889),
#   'average_precision': np.float64(0.42083665828517414)},
#  {'run': 4,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5866666666666666),
#   'average_precision': np.float64(0.42356125356125357)},
#  {'run': 4,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5977777777777777),
#   'average_precision': np.float64(0.4114311212822883)},
#  {'run': 4,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7166666666666666),
#   'average_precision': np.float64(0.5240675666047663)},
#  {'run': 4,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.6488888888888888),
#   'average_precision': np.float64(0.44263953148476637)},
#  {'run': 4,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6588888888888889),
#   'average_precision': np.float64(0.4597344839923793)},
#  {'run': 4,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6844444444444444),
#   'average_precision': np.float64(0.49308760683760683)},
#  {'run': 4,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6511111111111111),
#   'average_precision': np.float64(0.4585866570477755)},
#  {'run': 5,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.7477777777777778),
#   'average_precision': np.float64(0.564095349095349)},
#  {'run': 5,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7333333333333333),
#   'average_precision': np.float64(0.6284409991386736)},
#  {'run': 5,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.7355555555555556),
#   'average_precision': np.float64(0.5403831737435743)},
#  {'run': 5,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5955555555555556),
#   'average_precision': np.float64(0.43138833875675986)},
#  {'run': 5,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.668888888888889),
#   'average_precision': np.float64(0.5216349792054463)},
#  {'run': 5,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6466666666666667),
#   'average_precision': np.float64(0.49275280111410114)},
#  {'run': 5,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6933333333333334),
#   'average_precision': np.float64(0.5573246219757847)},
#  {'run': 5,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6755555555555556),
#   'average_precision': np.float64(0.4595344126314555)},
#  {'run': 5,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.5777777777777777),
#   'average_precision': np.float64(0.4581291214323507)},
#  {'run': 5,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.64),
#   'average_precision': np.float64(0.5259497778814181)},
#  {'run': 5,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.611111111111111),
#   'average_precision': np.float64(0.4360551667226892)},
#  {'run': 5,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7655555555555555),
#   'average_precision': np.float64(0.5904271003239011)},
#  {'run': 5,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.661111111111111),
#   'average_precision': np.float64(0.5143902332393381)},
#  {'run': 5,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6933333333333334),
#   'average_precision': np.float64(0.4781503650193021)},
#  {'run': 5,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6733333333333333),
#   'average_precision': np.float64(0.6091819422378011)},
#  {'run': 5,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6811111111111111),
#   'average_precision': np.float64(0.5421019084732973)},
#  {'run': 5,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.6722222222222223),
#   'average_precision': np.float64(0.6304396542621942)},
#  {'run': 5,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.678888888888889),
#   'average_precision': np.float64(0.45394602308928683)},
#  {'run': 5,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6444444444444444),
#   'average_precision': np.float64(0.4977622635860622)},
#  {'run': 5,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7577777777777778),
#   'average_precision': np.float64(0.6885052525052524)},
#  {'run': 6,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.7466666666666667),
#   'average_precision': np.float64(0.5538742862462327)},
#  {'run': 6,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.8666666666666667),
#   'average_precision': np.float64(0.698332369385001)},
#  {'run': 6,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.74),
#   'average_precision': np.float64(0.5050817986220351)},
#  {'run': 6,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7333333333333334),
#   'average_precision': np.float64(0.6421568135378877)},
#  {'run': 6,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.7777777777777778),
#   'average_precision': np.float64(0.6670881410450442)},
#  {'run': 6,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7222222222222222),
#   'average_precision': np.float64(0.4991205329969632)},
#  {'run': 6,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.8777777777777778),
#   'average_precision': np.float64(0.8268435988962304)},
#  {'run': 6,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7511111111111112),
#   'average_precision': np.float64(0.684499130525235)},
#  {'run': 6,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.7488888888888889),
#   'average_precision': np.float64(0.5773582846046614)},
#  {'run': 6,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.8077777777777777),
#   'average_precision': np.float64(0.647329536897848)},
#  {'run': 6,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.8377777777777778),
#   'average_precision': np.float64(0.6315028609993156)},
#  {'run': 6,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7555555555555555),
#   'average_precision': np.float64(0.5370944815991254)},
#  {'run': 6,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.7088888888888889),
#   'average_precision': np.float64(0.5273857623857623)},
#  {'run': 6,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7644444444444445),
#   'average_precision': np.float64(0.6202655086146547)},
#  {'run': 6,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.8555555555555555),
#   'average_precision': np.float64(0.7315611974232664)},
#  {'run': 6,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7655555555555555),
#   'average_precision': np.float64(0.6033167299464917)},
#  {'run': 6,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.7733333333333334),
#   'average_precision': np.float64(0.5559340487608738)},
#  {'run': 6,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7666666666666667),
#   'average_precision': np.float64(0.5968352436094372)},
#  {'run': 6,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.7888888888888889),
#   'average_precision': np.float64(0.6335456228941925)},
#  {'run': 6,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7077777777777778),
#   'average_precision': np.float64(0.4830384312491573)},
#  {'run': 7,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.6933333333333334),
#   'average_precision': np.float64(0.4699808470396706)},
#  {'run': 7,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5822222222222222),
#   'average_precision': np.float64(0.3708813489953841)},
#  {'run': 7,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6633333333333333),
#   'average_precision': np.float64(0.4736729154821967)},
#  {'run': 7,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6922222222222223),
#   'average_precision': np.float64(0.43185775154402606)},
#  {'run': 7,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.6122222222222222),
#   'average_precision': np.float64(0.4031484095518937)},
#  {'run': 7,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5966666666666667),
#   'average_precision': np.float64(0.3671026542319449)},
#  {'run': 7,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6244444444444444),
#   'average_precision': np.float64(0.47118860623096587)},
#  {'run': 7,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7555555555555555),
#   'average_precision': np.float64(0.5765631868418246)},
#  {'run': 7,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.6244444444444445),
#   'average_precision': np.float64(0.43130888356378555)},
#  {'run': 7,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7777777777777778),
#   'average_precision': np.float64(0.5961544265465833)},
#  {'run': 7,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.7266666666666666),
#   'average_precision': np.float64(0.4978979620165289)},
#  {'run': 7,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.76),
#   'average_precision': np.float64(0.6094347707250933)},
#  {'run': 7,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.6933333333333334),
#   'average_precision': np.float64(0.48350920679308806)},
#  {'run': 7,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.7622222222222222),
#   'average_precision': np.float64(0.5298992422436581)},
#  {'run': 7,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.7222222222222222),
#   'average_precision': np.float64(0.509982911718318)},
#  {'run': 7,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6244444444444445),
#   'average_precision': np.float64(0.3930285442302986)},
#  {'run': 7,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.6511111111111111),
#   'average_precision': np.float64(0.4180326040965876)},
#  {'run': 7,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.66),
#   'average_precision': np.float64(0.4309249852853857)},
#  {'run': 7,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6577777777777778),
#   'average_precision': np.float64(0.4188162590381373)},
#  {'run': 7,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7188888888888889),
#   'average_precision': np.float64(0.5296942668049847)},
#  {'run': 8,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.5422222222222223),
#   'average_precision': np.float64(0.3593645687750106)},
#  {'run': 8,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6155555555555555),
#   'average_precision': np.float64(0.43520903715021364)},
#  {'run': 8,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5533333333333333),
#   'average_precision': np.float64(0.44143877927432706)},
#  {'run': 8,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6911111111111111),
#   'average_precision': np.float64(0.4608811909673978)},
#  {'run': 8,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.6622222222222223),
#   'average_precision': np.float64(0.43557993912797494)},
#  {'run': 8,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6177777777777778),
#   'average_precision': np.float64(0.5147362012809167)},
#  {'run': 8,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.5633333333333334),
#   'average_precision': np.float64(0.3914693519041345)},
#  {'run': 8,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.671111111111111),
#   'average_precision': np.float64(0.44323858510372144)},
#  {'run': 8,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.648888888888889),
#   'average_precision': np.float64(0.4445928816164286)},
#  {'run': 8,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5633333333333334),
#   'average_precision': np.float64(0.36405504110412623)},
#  {'run': 8,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.58),
#   'average_precision': np.float64(0.37517716881219343)},
#  {'run': 8,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6511111111111112),
#   'average_precision': np.float64(0.39965600993051975)},
#  {'run': 8,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.5688888888888889),
#   'average_precision': np.float64(0.37125429914245334)},
#  {'run': 8,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5222222222222221),
#   'average_precision': np.float64(0.36569775605810706)},
#  {'run': 8,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6744444444444444),
#   'average_precision': np.float64(0.43453574547227797)},
#  {'run': 8,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.8077777777777777),
#   'average_precision': np.float64(0.6186051959612997)},
#  {'run': 8,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.6488888888888888),
#   'average_precision': np.float64(0.4743272908371976)},
#  {'run': 8,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6877777777777778),
#   'average_precision': np.float64(0.45528172772709014)},
#  {'run': 8,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.72),
#   'average_precision': np.float64(0.46557286630351646)},
#  {'run': 8,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7988888888888889),
#   'average_precision': np.float64(0.563613019048904)},
#  {'run': 9,
#   'hidden': 4,
#   'bonus_w': 0,
#   'auc': np.float64(0.5077777777777778),
#   'average_precision': np.float64(0.42447767511807744)},
#  {'run': 9,
#   'hidden': 4,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6155555555555556),
#   'average_precision': np.float64(0.44817921743654)},
#  {'run': 9,
#   'hidden': 4,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.56),
#   'average_precision': np.float64(0.46308884883235063)},
#  {'run': 9,
#   'hidden': 4,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6377777777777778),
#   'average_precision': np.float64(0.4120105336620763)},
#  {'run': 9,
#   'hidden': 8,
#   'bonus_w': 0,
#   'auc': np.float64(0.6088888888888889),
#   'average_precision': np.float64(0.48544217672373424)},
#  {'run': 9,
#   'hidden': 8,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5933333333333334),
#   'average_precision': np.float64(0.535791769491714)},
#  {'run': 9,
#   'hidden': 8,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.64),
#   'average_precision': np.float64(0.45881401077663475)},
#  {'run': 9,
#   'hidden': 8,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.7166666666666667),
#   'average_precision': np.float64(0.5779931564272531)},
#  {'run': 9,
#   'hidden': 16,
#   'bonus_w': 0,
#   'auc': np.float64(0.6088888888888888),
#   'average_precision': np.float64(0.41680219335302504)},
#  {'run': 9,
#   'hidden': 16,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6877777777777777),
#   'average_precision': np.float64(0.5377214886810522)},
#  {'run': 9,
#   'hidden': 16,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.56),
#   'average_precision': np.float64(0.3820912557139738)},
#  {'run': 9,
#   'hidden': 16,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6855555555555557),
#   'average_precision': np.float64(0.5203485194860916)},
#  {'run': 9,
#   'hidden': 32,
#   'bonus_w': 0,
#   'auc': np.float64(0.7022222222222223),
#   'average_precision': np.float64(0.4830472247203881)},
#  {'run': 9,
#   'hidden': 32,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.5733333333333333),
#   'average_precision': np.float64(0.3685905068108656)},
#  {'run': 9,
#   'hidden': 32,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6366666666666667),
#   'average_precision': np.float64(0.45005457698236695)},
#  {'run': 9,
#   'hidden': 32,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.6933333333333334),
#   'average_precision': np.float64(0.5173400655021462)},
#  {'run': 9,
#   'hidden': 64,
#   'bonus_w': 0,
#   'auc': np.float64(0.5733333333333334),
#   'average_precision': np.float64(0.38786071067993594)},
#  {'run': 9,
#   'hidden': 64,
#   'bonus_w': 0.001,
#   'auc': np.float64(0.6777777777777777),
#   'average_precision': np.float64(0.5119018453614089)},
#  {'run': 9,
#   'hidden': 64,
#   'bonus_w': 0.01,
#   'auc': np.float64(0.6644444444444444),
#   'average_precision': np.float64(0.49696075824666797)},
#  {'run': 9,
#   'hidden': 64,
#   'bonus_w': 0.1,
#   'auc': np.float64(0.5888888888888889),
#   'average_precision': np.float64(0.4091465452444455)}]

# %%
df = pd.DataFrame(results)
df_res = df.groupby(['hidden', 'bonus_w'])[['auc', 'average_precision']].mean()
print(df.groupby(['hidden', 'bonus_w'])[['auc', 'average_precision']].mean())
# Out:
#                      auc  average_precision
# hidden bonus_w
# 4      0.000    0.650000           0.497210
#        0.001    0.616222           0.467220
#        0.010    0.616111           0.454067
#        0.100    0.603444           0.435903
# 8      0.000    0.614444           0.467741
#        0.001    0.599333           0.465538
#        0.010    0.629444           0.487211
#        0.100    0.656111           0.493841
# 16     0.000    0.609667           0.448643
#        0.001    0.675556           0.516946
#        0.010    0.644667           0.463776
#        0.100    0.671333           0.492227
# 32     0.000    0.646444           0.462767
#        0.001    0.628667           0.448460
#        0.010    0.673778           0.507156
#        0.100    0.684333           0.499542
# 64     0.000    0.633000           0.470792
#        0.001    0.650111           0.474503
#        0.010    0.659556           0.469725
#        0.100    0.671889           0.490795

# %%
ax = df_res.plot(kind='bar', figsize=(8, 5))
plt.title("SAGE Performance vs Hidden Size")
plt.xlabel("Hidden Size")
plt.ylabel("Score")
plt.ylim(0.4, 0.8)

plt.legend(title="Metric")
plt.tight_layout()
plt.show()
